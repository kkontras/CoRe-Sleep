# %%
import sys
import os
import numpy as np

sys.exc_info()
os.chdir('/users/sista/kkontras/Documents/Sleep_Project/')


from posthoc.Helpers.Helper_Importer import Importer
from posthoc.Helpers.Helper_Validator import Validator
from posthoc.Helpers.Helper_LogsPlotter import LogsPlotter
from posthoc.Helpers.Helper_Generate_n_Compare import Generate_n_Compare

# %%
config_list = [

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_0e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_0e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_0e_0o.json",
    # #
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_50e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_50e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_50e_0o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_100e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_100e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_100e_0o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_200e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_200e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_200e_0o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_400e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_400e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_400e_0o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_600e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_600e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_600e_0o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_1000e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_1000e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_1000e_0o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_1500e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_1500e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_1500e_0o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_2000e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_2000e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_2000e_0o.json",

]
count = 0
multi_fold_results = {}

eeg, eog, mm = [], [], []
eeg_std, eog_std, mm_std = [], [], []
for i, config_name in enumerate(config_list):
    for fold in range(1):
        # fold = len(config_list)*i + fold
        importer = Importer(config_name=config_name, device="cuda:0", fold=fold)
        try:
            importer.load_checkpoint()
        except:
            print("We could not load {}".format(config_name))
            continue
        plotter = LogsPlotter(config=importer.config, logs=importer.checkpoint["logs"])

        importer.fold = count*10 + fold
        # try:
        #     importer.change_config(attr="model.args.shared_preds", value=False)
        #     a = importer.get_model()
        #     importer._my_numel(a)
        # except:
        #     print("We could not load {}".format(config_name))
        #     continue

        multi_fold_results = importer.print_progress(multi_fold_results=multi_fold_results, latex_version=False)
        # importer.print_progress_aggregated(multi_fold_results=multi_fold_results, latex_version=True)


        if (i+1)%3 == 0:
            print(multi_fold_results.keys())
            eeg.append(np.array([multi_fold_results[i]["k"]["eeg"] for i in multi_fold_results]).mean())
            eog.append(np.array([multi_fold_results[i]["k"]["eog"] for i in multi_fold_results]).mean())
            mm.append(np.array([multi_fold_results[i]["k"]["combined"] for i in multi_fold_results]).mean())
            eeg_std.append(np.array([multi_fold_results[i]["k"]["eeg"] for i in multi_fold_results]).std())
            eog_std.append(np.array([multi_fold_results[i]["k"]["eog"] for i in multi_fold_results]).std())
            mm_std.append(np.array([multi_fold_results[i]["k"]["combined"] for i in multi_fold_results]).std())
            multi_fold_results = {}

        # plotter.sleep_plot_losses()
        # plotter.sleep_plot_performance()
    count +=1

a_eeg, a_eog, a_mm = np.array(eeg), np.array(eog), np.array(mm)
a_eeg_std, a_eog_std, a_mm_std = np.array(eeg_std), np.array(eog_std), np.array(mm_std)

config_list = [

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_0e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_0e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_0e_0o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_0e_50o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_0e_50o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_0e_50o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_0e_100o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_0e_100o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_0e_100o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_0e_200o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_0e_200o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_0e_200o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_0e_400o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_0e_400o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_0e_400o.json",
    #
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_0e_600o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_0e_600o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_0e_600o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_0e_1000o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_0e_1000o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_0e_1000o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_0e_1500o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_0e_1500o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_0e_1500o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_0e_2000o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_0e_2000o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_0e_2000o.json",

]
count = 0
multi_fold_results = {}

eeg, eog, mm = [], [], []
eeg_std, eog_std, mm_std = [], [], []
for i, config_name in enumerate(config_list):
    for fold in range(1):
        # fold = len(config_list)*i + fold
        importer = Importer(config_name=config_name, device="cuda:0", fold=fold)
        try:
            importer.load_checkpoint()
        except:
            print("We could not load {}".format(config_name))
            continue
        plotter = LogsPlotter(config=importer.config, logs=importer.checkpoint["logs"])

        importer.fold = count*10 + fold
        # try:
        #     importer.change_config(attr="model.args.shared_preds", value=False)
        #     a = importer.get_model()
        #     importer._my_numel(a)
        # except:
        #     print("We could not load {}".format(config_name))
        #     continue

        multi_fold_results = importer.print_progress(multi_fold_results=multi_fold_results, latex_version=False)
        # importer.print_progress_aggregated(multi_fold_results=multi_fold_results, latex_version=True)


        if (i+1)%3 == 0:
            print(multi_fold_results.keys())
            eeg.append(np.array([multi_fold_results[i]["k"]["eeg"] for i in multi_fold_results]).mean())
            eog.append(np.array([multi_fold_results[i]["k"]["eog"] for i in multi_fold_results]).mean())
            mm.append(np.array([multi_fold_results[i]["k"]["combined"] for i in multi_fold_results]).mean())
            eeg_std.append(np.array([multi_fold_results[i]["k"]["eeg"] for i in multi_fold_results]).std())
            eog_std.append(np.array([multi_fold_results[i]["k"]["eog"] for i in multi_fold_results]).std())
            mm_std.append(np.array([multi_fold_results[i]["k"]["combined"] for i in multi_fold_results]).std())
            multi_fold_results = {}

        # plotter.sleep_plot_losses()
        # plotter.sleep_plot_performance()
    count +=1

b_eeg, b_eog, b_mm = np.array(eeg), np.array(eog), np.array(mm)
b_eeg_std, b_eog_std, b_mm_std = np.array(eeg_std), np.array(eog_std), np.array(mm_std)


config_list = [

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_0e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_0e_0o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_0e_0o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_50e_50o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_50e_50o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_50e_50o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_100e_100o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_100e_100o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_100e_100o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_unsharedpreds_100p_200e_200o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_unsharedpreds_100p_200e_200o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_unsharedpreds_100p_200e_200o.json",

    # "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_200e_200o.json",
    # "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_200e_200o.json",
    # "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_200e_200o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_400e_400o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_400e_400o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_400e_400o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_600e_600o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_600e_600o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_600e_600o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_1000e_1000o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_1000e_1000o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_1000e_1000o.json",

    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_1500e_1500o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_1500e_1500o.json",
    "./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_1500e_1500o.json",

]
count = 0
multi_fold_results = {}

eeg, eog, mm = [], [], []
eeg_std, eog_std, mm_std = [], [], []
for i, config_name in enumerate(config_list):
    for fold in range(1):
        # fold = len(config_list)*i + fold
        importer = Importer(config_name=config_name, device="cuda:0", fold=fold)
        try:
            importer.load_checkpoint()
        except:
            print("We could not load {}".format(config_name))
            continue
        plotter = LogsPlotter(config=importer.config, logs=importer.checkpoint["logs"])

        importer.fold = count*10 + fold
        # try:
        #     importer.change_config(attr="model.args.shared_preds", value=False)
        #     a = importer.get_model()
        #     importer._my_numel(a)
        # except:
        #     print("We could not load {}".format(config_name))
        #     continue

        multi_fold_results = importer.print_progress(multi_fold_results=multi_fold_results, latex_version=False)
        # importer.print_progress_aggregated(multi_fold_results=multi_fold_results, latex_version=True)


        if (i+1)%3 == 0:
            print(multi_fold_results.keys())
            eeg.append(np.array([multi_fold_results[i]["k"]["eeg"] for i in multi_fold_results]).mean())
            eog.append(np.array([multi_fold_results[i]["k"]["eog"] for i in multi_fold_results]).mean())
            mm.append(np.array([multi_fold_results[i]["k"]["combined"] for i in multi_fold_results]).mean())
            eeg_std.append(np.array([multi_fold_results[i]["k"]["eeg"] for i in multi_fold_results]).std())
            eog_std.append(np.array([multi_fold_results[i]["k"]["eog"] for i in multi_fold_results]).std())
            mm_std.append(np.array([multi_fold_results[i]["k"]["combined"] for i in multi_fold_results]).std())
            multi_fold_results = {}

        # plotter.sleep_plot_losses()
        # plotter.sleep_plot_performance()
    count +=1

both_eeg, both_eog, both_mm = np.array(eeg), np.array(eog), np.array(mm)
both_eeg_std, both_eog_std, both_mm_std = np.array(eeg_std), np.array(eog_std), np.array(mm_std)
# Out:
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_0e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial2_pt_incomplete_100p_0e_0o.pth.tar
# -- Best Validation --
# Step: 60, No_improve: 336 ce_loss_combined : 0.392099 total : 1.410688 Acc_combined: 85.49 K_combined: 0.797 F1_combined: 76.35 F1_perclass_combined: [89.92, 35.7, 86.67, 83.65, 85.8]
# Step: 60, No_improve: 336 ce_loss_eeg : 0.476924 total : 1.410688 Acc_eeg: 82.70 K_eeg: 0.758 F1_eeg: 72.89 F1_perclass_eeg: [88.24, 30.97, 84.13, 83.76, 77.34]
# Step: 60, No_improve: 336 ce_loss_eog : 0.541665 total : 1.410688 Acc_eog: 79.64 K_eog: 0.714 F1_eog: 67.31 F1_perclass_eog: [85.92, 14.23, 80.28, 73.11, 83.03]
# --- Post Test ---
# combined Acc: 86.0 K: 0.803 F1: 76.3 F1_perclass: [90.4, 34.1, 87.2, 83.5, 86.6]
# combined &  86.0 & 0.803 & 76.3 & 90.4 & 34.1 & 87.2 & 83.5 & 86.6 &
# eeg Acc: 83.0 K: 0.761 F1: 72.7 F1_perclass: [88.0, 29.6, 84.8, 82.6, 78.4]
# eeg &  83.0 & 0.761 & 72.7 & 88.0 & 29.6 & 84.8 & 82.6 & 78.4 &
# eog Acc: 79.9 K: 0.718 F1: 67.3 F1_perclass: [85.4, 13.9, 81.0, 73.4, 82.9]
# eog &  79.9 & 0.718 & 67.3 & 85.4 & 13.9 & 81.0 & 73.4 & 82.9 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_0e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_pt_incomplete_100p_0e_0o.pth.tar
# -- Best Validation --
# Step: 64, No_improve: 332 ce_loss_combined : 0.438388 total : 1.456262 Acc_combined: 85.74 K_combined: 0.803 F1_combined: 77.01 F1_perclass_combined: [90.43, 38.09, 86.47, 82.26, 87.8]
# Step: 64, No_improve: 332 ce_loss_eeg : 0.516627 total : 1.456262 Acc_eeg: 83.97 K_eeg: 0.778 F1_eeg: 74.24 F1_perclass_eeg: [89.33, 31.97, 84.78, 83.81, 81.32]
# Step: 64, No_improve: 332 ce_loss_eog : 0.501247 total : 1.456262 Acc_eog: 81.54 K_eog: 0.741 F1_eog: 68.80 F1_perclass_eog: [86.56, 14.02, 82.27, 76.28, 84.84]
# --- Post Test ---
# combined Acc: 85.3 K: 0.794 F1: 76.7 F1_perclass: [89.7, 39.1, 86.6, 81.5, 86.6]
# combined &  85.3 & 0.794 & 76.7 & 89.7 & 39.1 & 86.6 & 81.5 & 86.6 &
# eeg Acc: 83.1 K: 0.764 F1: 73.4 F1_perclass: [88.6, 32.8, 84.6, 82.4, 78.8]
# eeg &  83.1 & 0.764 & 73.4 & 88.6 & 32.8 & 84.6 & 82.4 & 78.8 &
# eog Acc: 80.5 K: 0.723 F1: 67.7 F1_perclass: [85.6, 14.7, 81.8, 73.1, 83.5]
# eog &  80.5 & 0.723 & 67.7 & 85.6 & 14.7 & 81.8 & 73.1 & 83.5 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_0e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_incomplete_100p_0e_0o.pth.tar
# -- Best Validation --
# Step: 58, No_improve: 341 ce_loss_combined : 0.427301 total : 1.542237 Acc_combined: 85.33 K_combined: 0.796 F1_combined: 76.95 F1_perclass_combined: [90.06, 39.18, 86.06, 82.68, 86.77]
# Step: 58, No_improve: 341 ce_loss_eeg : 0.526975 total : 1.542237 Acc_eeg: 81.97 K_eeg: 0.747 F1_eeg: 72.70 F1_perclass_eeg: [87.42, 34.43, 83.6, 82.37, 75.68]
# Step: 58, No_improve: 341 ce_loss_eog : 0.587960 total : 1.542237 Acc_eog: 80.39 K_eog: 0.722 F1_eog: 65.93 F1_perclass_eog: [85.83, 5.27, 81.39, 73.17, 83.97]
# --- Post Test ---
# combined Acc: 85.2 K: 0.792 F1: 76.4 F1_perclass: [90.5, 37.6, 86.1, 81.1, 86.8]
# combined &  85.2 & 0.792 & 76.4 & 90.5 & 37.6 & 86.1 & 81.0 & 86.8 &
# eeg Acc: 81.3 K: 0.736 F1: 72.0 F1_perclass: [87.2, 34.3, 83.5, 81.0, 74.1]
# eeg &  81.3 & 0.736 & 72.0 & 87.2 & 34.3 & 83.5 & 81.0 & 74.1 &
# eog Acc: 80.3 K: 0.719 F1: 65.8 F1_perclass: [85.1, 5.7, 81.7, 72.3, 84.0]
# eog &  80.3 & 0.719 & 65.8 & 85.1 & 5.7 & 81.7 & 72.2 & 84.0 &
# dict_keys([0, 10, 20])
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_50e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial2_pt_incomplete_100p_50e_0o.pth.tar
# -- Best Validation --
# Step: 94, No_improve: 50 ce_loss_combined : 0.409006 total : 1.421138 Acc_combined: 85.95 K_combined: 0.804 F1_combined: 77.87 F1_perclass_combined: [90.6, 41.11, 87.15, 83.99, 86.51]
# Step: 94, No_improve: 50 ce_loss_eeg : 0.461722 total : 1.421138 Acc_eeg: 83.94 K_eeg: 0.775 F1_eeg: 75.25 F1_perclass_eeg: [89.21, 37.47, 85.46, 84.15, 79.96]
# Step: 94, No_improve: 50 ce_loss_eog : 0.550410 total : 1.421138 Acc_eog: 79.78 K_eog: 0.715 F1_eog: 67.84 F1_perclass_eog: [85.99, 16.47, 80.65, 72.31, 83.81]
# --- Post Test ---
# combined Acc: 86.5 K: 0.811 F1: 77.9 F1_perclass: [91.0, 39.7, 87.7, 83.9, 87.5]
# combined &  86.5 & 0.811 & 77.9 & 91.0 & 39.7 & 87.7 & 83.9 & 87.5 &
# eeg Acc: 84.4 K: 0.781 F1: 75.5 F1_perclass: [89.4, 36.9, 86.0, 83.5, 81.4]
# eeg &  84.4 & 0.781 & 75.5 & 89.4 & 36.9 & 86.0 & 83.5 & 81.4 &
# eog Acc: 80.4 K: 0.723 F1: 68.0 F1_perclass: [85.7, 15.7, 81.7, 73.2, 83.7]
# eog &  80.4 & 0.723 & 68.0 & 85.7 & 15.7 & 81.7 & 73.2 & 83.7 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_50e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_pt_incomplete_100p_50e_0o.pth.tar
# -- Best Validation --
# Step: 87, No_improve: 50 ce_loss_combined : 0.434031 total : 1.410614 Acc_combined: 85.75 K_combined: 0.802 F1_combined: 77.57 F1_perclass_combined: [90.16, 40.38, 86.42, 83.83, 87.05]
# Step: 87, No_improve: 50 ce_loss_eeg : 0.460084 total : 1.410614 Acc_eeg: 84.26 K_eeg: 0.782 F1_eeg: 76.00 F1_perclass_eeg: [89.26, 39.47, 85.05, 83.65, 82.58]
# Step: 87, No_improve: 50 ce_loss_eog : 0.516500 total : 1.410614 Acc_eog: 81.32 K_eog: 0.736 F1_eog: 66.87 F1_perclass_eog: [86.41, 4.36, 81.85, 77.44, 84.32]
# --- Post Test ---
# combined Acc: 85.3 K: 0.794 F1: 77.0 F1_perclass: [89.7, 40.8, 86.8, 81.8, 85.9]
# combined &  85.3 & 0.794 & 77.0 & 89.7 & 40.8 & 86.8 & 81.8 & 85.9 &
# eeg Acc: 83.3 K: 0.766 F1: 74.8 F1_perclass: [88.9, 38.6, 84.9, 82.1, 79.3]
# eeg &  83.3 & 0.766 & 74.8 & 88.9 & 38.6 & 84.8 & 82.1 & 79.3 &
# eog Acc: 80.3 K: 0.718 F1: 66.0 F1_perclass: [85.5, 5.9, 81.5, 74.1, 82.9]
# eog &  80.3 & 0.718 & 66.0 & 85.5 & 5.9 & 81.5 & 74.1 & 82.9 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_50e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_incomplete_100p_50e_0o.pth.tar
# -- Best Validation --
# Step: 91, No_improve: 307 ce_loss_combined : 0.442226 total : 1.541705 Acc_combined: 85.86 K_combined: 0.804 F1_combined: 77.89 F1_perclass_combined: [90.11, 41.26, 86.4, 84.38, 87.29]
# Step: 91, No_improve: 307 ce_loss_eeg : 0.505657 total : 1.541705 Acc_eeg: 83.68 K_eeg: 0.775 F1_eeg: 75.08 F1_perclass_eeg: [89.1, 37.47, 84.32, 84.14, 80.36]
# Step: 91, No_improve: 307 ce_loss_eog : 0.593822 total : 1.541705 Acc_eog: 80.76 K_eog: 0.730 F1_eog: 68.18 F1_perclass_eog: [86.03, 13.16, 81.41, 76.44, 83.86]
# --- Post Test ---
# combined Acc: 86.0 K: 0.805 F1: 77.8 F1_perclass: [90.7, 40.8, 86.8, 82.9, 88.0]
# combined &  86.0 & 0.805 & 77.8 & 90.8 & 40.8 & 86.8 & 82.9 & 88.0 &
# eeg Acc: 83.1 K: 0.766 F1: 74.6 F1_perclass: [88.4, 37.7, 84.4, 82.6, 79.9]
# eeg &  83.1 & 0.766 & 74.6 & 88.4 & 37.7 & 84.4 & 82.6 & 79.9 &
# eog Acc: 80.4 K: 0.724 F1: 67.8 F1_perclass: [85.4, 12.8, 81.3, 74.9, 84.5]
# eog &  80.4 & 0.724 & 67.8 & 85.4 & 12.8 & 81.2 & 75.0 & 84.5 &
# dict_keys([30, 40, 50])
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_100e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial2_pt_incomplete_100p_100e_0o.pth.tar
# -- Best Validation --
# Step: 132, No_improve: 50 ce_loss_combined : 0.393726 total : 1.382742 Acc_combined: 86.27 K_combined: 0.808 F1_combined: 78.07 F1_perclass_combined: [90.68, 41.01, 87.87, 84.2, 86.6]
# Step: 132, No_improve: 50 ce_loss_eeg : 0.439241 total : 1.382742 Acc_eeg: 84.58 K_eeg: 0.784 F1_eeg: 76.19 F1_perclass_eeg: [89.67, 39.85, 86.17, 84.33, 80.92]
# Step: 132, No_improve: 50 ce_loss_eog : 0.549775 total : 1.382742 Acc_eog: 79.81 K_eog: 0.715 F1_eog: 67.65 F1_perclass_eog: [85.66, 16.07, 80.97, 71.65, 83.9]
# --- Post Test ---
# combined Acc: 86.9 K: 0.815 F1: 78.5 F1_perclass: [91.4, 40.8, 88.1, 83.8, 88.1]
# combined &  86.9 & 0.815 & 78.5 & 91.4 & 40.9 & 88.1 & 83.8 & 88.1 &
# eeg Acc: 85.2 K: 0.791 F1: 76.5 F1_perclass: [90.1, 39.1, 86.6, 83.9, 82.6]
# eeg &  85.2 & 0.791 & 76.5 & 90.1 & 39.1 & 86.6 & 83.9 & 82.6 &
# eog Acc: 80.6 K: 0.724 F1: 67.9 F1_perclass: [85.8, 15.4, 82.1, 72.3, 84.0]
# eog &  80.6 & 0.724 & 67.9 & 85.8 & 15.4 & 82.1 & 72.3 & 84.0 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_100e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_pt_incomplete_100p_100e_0o.pth.tar
# -- Best Validation --
# Step: 128, No_improve: 50 ce_loss_combined : 0.424895 total : 1.350956 Acc_combined: 86.45 K_combined: 0.812 F1_combined: 78.55 F1_perclass_combined: [90.59, 42.49, 86.92, 84.31, 88.45]
# Step: 128, No_improve: 50 ce_loss_eeg : 0.416360 total : 1.350956 Acc_eeg: 85.04 K_eeg: 0.793 F1_eeg: 76.56 F1_perclass_eeg: [89.82, 39.01, 85.74, 84.16, 84.1]
# Step: 128, No_improve: 50 ce_loss_eog : 0.509700 total : 1.350956 Acc_eog: 81.44 K_eog: 0.739 F1_eog: 67.52 F1_perclass_eog: [86.73, 6.85, 81.74, 77.29, 85.0]
# --- Post Test ---
# combined Acc: 85.8 K: 0.801 F1: 77.6 F1_perclass: [89.9, 41.5, 87.0, 82.8, 86.9]
# combined &  85.8 & 0.801 & 77.6 & 89.9 & 41.5 & 87.0 & 82.8 & 86.9 &
# eeg Acc: 84.2 K: 0.778 F1: 75.3 F1_perclass: [89.5, 37.7, 85.7, 82.9, 80.8]
# eeg &  84.2 & 0.778 & 75.3 & 89.5 & 37.7 & 85.7 & 82.9 & 80.8 &
# eog Acc: 80.4 K: 0.722 F1: 66.7 F1_perclass: [85.6, 8.6, 81.5, 74.1, 83.3]
# eog &  80.4 & 0.722 & 66.7 & 85.7 & 8.7 & 81.5 & 74.2 & 83.3 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_100e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_incomplete_100p_100e_0o.pth.tar
# -- Best Validation --
# Step: 125, No_improve: 267 ce_loss_combined : 0.429507 total : 1.486115 Acc_combined: 86.45 K_combined: 0.811 F1_combined: 78.26 F1_perclass_combined: [90.59, 41.09, 87.08, 84.79, 87.76]
# Step: 125, No_improve: 267 ce_loss_eeg : 0.450741 total : 1.486115 Acc_eeg: 84.64 K_eeg: 0.787 F1_eeg: 75.90 F1_perclass_eeg: [89.77, 37.69, 85.28, 84.66, 82.12]
# Step: 125, No_improve: 267 ce_loss_eog : 0.605867 total : 1.486115 Acc_eog: 80.57 K_eog: 0.725 F1_eog: 66.81 F1_perclass_eog: [85.82, 8.79, 81.59, 74.08, 83.74]
# --- Post Test ---
# combined Acc: 86.5 K: 0.811 F1: 78.0 F1_perclass: [90.9, 39.8, 87.5, 83.4, 88.4]
# combined &  86.5 & 0.811 & 78.0 & 90.9 & 39.8 & 87.5 & 83.4 & 88.4 &
# eeg Acc: 84.2 K: 0.779 F1: 75.3 F1_perclass: [89.2, 36.9, 85.4, 83.4, 81.4]
# eeg &  84.2 & 0.779 & 75.3 & 89.2 & 36.9 & 85.4 & 83.4 & 81.4 &
# eog Acc: 80.5 K: 0.723 F1: 66.6 F1_perclass: [85.4, 8.6, 81.9, 72.6, 84.6]
# eog &  80.5 & 0.723 & 66.6 & 85.4 & 8.6 & 81.9 & 72.6 & 84.6 &
# dict_keys([60, 70, 80])
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_200e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial2_pt_incomplete_100p_200e_0o.pth.tar
# -- Best Validation --
# Step: 147, No_improve: 50 ce_loss_combined : 0.375626 total : 1.344369 Acc_combined: 86.29 K_combined: 0.809 F1_combined: 78.31 F1_perclass_combined: [90.71, 42.03, 87.52, 84.71, 86.6]
# Step: 147, No_improve: 50 ce_loss_eeg : 0.421240 total : 1.344369 Acc_eeg: 84.55 K_eeg: 0.784 F1_eeg: 75.91 F1_perclass_eeg: [89.53, 38.36, 86.04, 84.65, 80.98]
# Step: 147, No_improve: 50 ce_loss_eog : 0.547503 total : 1.344369 Acc_eog: 79.97 K_eog: 0.717 F1_eog: 66.43 F1_perclass_eog: [85.89, 9.36, 81.12, 72.26, 83.51]
# --- Post Test ---
# combined Acc: 86.8 K: 0.815 F1: 78.4 F1_perclass: [91.3, 41.0, 88.0, 84.0, 87.7]
# combined &  86.8 & 0.815 & 78.4 & 91.3 & 41.0 & 88.0 & 84.0 & 87.7 &
# eeg Acc: 85.5 K: 0.796 F1: 76.6 F1_perclass: [90.4, 38.2, 86.8, 84.5, 83.3]
# eeg &  85.5 & 0.796 & 76.6 & 90.4 & 38.2 & 86.8 & 84.5 & 83.3 &
# eog Acc: 80.4 K: 0.722 F1: 66.5 F1_perclass: [85.6, 9.1, 81.9, 72.9, 83.1]
# eog &  80.4 & 0.722 & 66.5 & 85.6 & 9.1 & 81.9 & 72.9 & 83.1 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_200e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_pt_incomplete_100p_200e_0o.pth.tar
# -- Best Validation --
# Step: 136, No_improve: 51 ce_loss_combined : 0.416690 total : 1.343526 Acc_combined: 86.41 K_combined: 0.812 F1_combined: 78.30 F1_perclass_combined: [90.65, 41.24, 86.92, 84.93, 87.78]
# Step: 136, No_improve: 51 ce_loss_eeg : 0.402646 total : 1.343526 Acc_eeg: 85.37 K_eeg: 0.797 F1_eeg: 76.98 F1_perclass_eeg: [90.39, 39.54, 85.96, 85.0, 83.98]
# Step: 136, No_improve: 51 ce_loss_eog : 0.524189 total : 1.343526 Acc_eog: 80.82 K_eog: 0.731 F1_eog: 66.35 F1_perclass_eog: [85.71, 3.32, 81.22, 78.08, 83.41]
# --- Post Test ---
# combined Acc: 86.0 K: 0.805 F1: 77.8 F1_perclass: [90.2, 41.1, 87.3, 83.5, 86.8]
# combined &  86.0 & 0.805 & 77.8 & 90.2 & 41.1 & 87.3 & 83.5 & 86.8 &
# eeg Acc: 84.7 K: 0.786 F1: 76.0 F1_perclass: [89.8, 38.9, 86.2, 83.5, 81.8]
# eeg &  84.7 & 0.786 & 76.0 & 89.8 & 38.9 & 86.2 & 83.5 & 81.8 &
# eog Acc: 79.7 K: 0.711 F1: 65.1 F1_perclass: [84.9, 3.6, 80.9, 74.4, 81.6]
# eog &  79.7 & 0.711 & 65.1 & 84.9 & 3.6 & 80.8 & 74.4 & 81.6 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_200e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_incomplete_100p_200e_0o.pth.tar
# -- Best Validation --
# Step: 214, No_improve: 100 ce_loss_combined : 0.424955 total : 1.481844 Acc_combined: 86.51 K_combined: 0.812 F1_combined: 78.89 F1_perclass_combined: [91.03, 44.54, 87.2, 83.78, 87.89]
# Step: 214, No_improve: 100 ce_loss_eeg : 0.454458 total : 1.481844 Acc_eeg: 85.37 K_eeg: 0.797 F1_eeg: 77.01 F1_perclass_eeg: [90.55, 40.68, 86.16, 84.41, 83.27]
# Step: 214, No_improve: 100 ce_loss_eog : 0.602431 total : 1.481844 Acc_eog: 80.80 K_eog: 0.731 F1_eog: 69.06 F1_perclass_eog: [85.55, 18.36, 81.74, 75.35, 84.31]
# --- Post Test ---
# combined Acc: 86.7 K: 0.814 F1: 78.7 F1_perclass: [91.4, 42.8, 87.7, 82.7, 88.9]
# combined &  86.7 & 0.814 & 78.7 & 91.4 & 42.8 & 87.7 & 82.7 & 88.9 &
# eeg Acc: 85.2 K: 0.792 F1: 76.7 F1_perclass: [90.1, 40.1, 86.4, 83.7, 83.4]
# eeg &  85.2 & 0.792 & 76.7 & 90.1 & 40.1 & 86.4 & 83.7 & 83.4 &
# eog Acc: 80.5 K: 0.726 F1: 68.7 F1_perclass: [84.9, 17.7, 81.6, 74.1, 84.9]
# eog &  80.5 & 0.726 & 68.7 & 84.9 & 17.7 & 81.6 & 74.1 & 84.9 &
# dict_keys([90, 100, 110])
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_400e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_incomplete_100p_400e_0o.pth.tar
# -- Best Validation --
# Step: 316, No_improve: 100 ce_loss_combined : 0.393260 total : 1.407178 Acc_combined: 86.93 K_combined: 0.819 F1_combined: 79.61 F1_perclass_combined: [91.41, 45.54, 87.37, 85.19, 88.52]
# Step: 316, No_improve: 100 ce_loss_eeg : 0.418096 total : 1.407178 Acc_eeg: 85.62 K_eeg: 0.801 F1_eeg: 77.29 F1_perclass_eeg: [90.49, 40.55, 86.15, 85.8, 83.47]
# Step: 316, No_improve: 100 ce_loss_eog : 0.595821 total : 1.407178 Acc_eog: 80.20 K_eog: 0.723 F1_eog: 66.67 F1_perclass_eog: [84.56, 7.76, 80.71, 76.44, 83.89]
# --- Post Test ---
# combined Acc: 86.9 K: 0.817 F1: 79.1 F1_perclass: [91.7, 43.4, 87.7, 84.0, 88.8]
# combined &  86.9 & 0.817 & 79.1 & 91.7 & 43.4 & 87.7 & 84.0 & 88.8 &
# eeg Acc: 85.1 K: 0.793 F1: 76.7 F1_perclass: [89.9, 39.8, 86.2, 84.3, 83.4]
# eeg &  85.1 & 0.793 & 76.7 & 89.9 & 39.8 & 86.2 & 84.3 & 83.4 &
# eog Acc: 79.3 K: 0.710 F1: 65.8 F1_perclass: [83.0, 6.6, 80.0, 74.8, 84.5]
# eog &  79.3 & 0.710 & 65.8 & 83.0 & 6.6 & 80.0 & 74.8 & 84.5 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_400e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_pt_incomplete_100p_400e_0o.pth.tar
# -- Best Validation --
# Step: 361, No_improve: 100 ce_loss_combined : 0.412219 total : 1.285789 Acc_combined: 86.90 K_combined: 0.819 F1_combined: 79.57 F1_perclass_combined: [90.85, 45.51, 87.25, 85.43, 88.83]
# Step: 361, No_improve: 100 ce_loss_eeg : 0.375443 total : 1.285789 Acc_eeg: 86.27 K_eeg: 0.810 F1_eeg: 78.35 F1_perclass_eeg: [90.78, 42.31, 86.73, 85.65, 86.24]
# Step: 361, No_improve: 100 ce_loss_eog : 0.498127 total : 1.285789 Acc_eog: 81.68 K_eog: 0.743 F1_eog: 68.79 F1_perclass_eog: [86.37, 11.98, 81.96, 78.44, 85.18]
# --- Post Test ---
# combined Acc: 86.3 K: 0.809 F1: 78.5 F1_perclass: [90.3, 43.4, 87.4, 84.0, 87.6]
# combined &  86.3 & 0.809 & 78.5 & 90.2 & 43.4 & 87.4 & 84.0 & 87.6 &
# eeg Acc: 85.8 K: 0.801 F1: 77.6 F1_perclass: [90.5, 41.9, 87.0, 84.4, 84.4]
# eeg &  85.8 & 0.801 & 77.6 & 90.5 & 41.9 & 87.0 & 84.5 & 84.4 &
# eog Acc: 80.4 K: 0.722 F1: 67.6 F1_perclass: [85.3, 13.1, 81.4, 74.4, 83.7]
# eog &  80.4 & 0.722 & 67.6 & 85.3 & 13.1 & 81.4 & 74.4 & 83.8 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_400e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial2_pt_incomplete_100p_400e_0o.pth.tar
# -- Best Validation --
# Step: 209, No_improve: 50 ce_loss_combined : 0.385890 total : 1.369482 Acc_combined: 86.38 K_combined: 0.810 F1_combined: 78.55 F1_perclass_combined: [91.01, 43.2, 87.75, 84.71, 86.09]
# Step: 209, No_improve: 50 ce_loss_eeg : 0.412558 total : 1.369482 Acc_eeg: 84.81 K_eeg: 0.788 F1_eeg: 76.71 F1_perclass_eeg: [89.78, 41.31, 86.25, 84.78, 81.44]
# Step: 209, No_improve: 50 ce_loss_eog : 0.571034 total : 1.369482 Acc_eog: 78.81 K_eog: 0.702 F1_eog: 65.54 F1_perclass_eog: [85.3, 8.69, 79.61, 72.8, 81.31]
# --- Post Test ---
# combined Acc: 86.9 K: 0.816 F1: 78.8 F1_perclass: [91.3, 43.0, 88.1, 84.1, 87.7]
# combined &  86.9 & 0.816 & 78.8 & 91.3 & 43.0 & 88.1 & 84.1 & 87.7 &
# eeg Acc: 85.9 K: 0.802 F1: 77.5 F1_perclass: [90.7, 41.0, 87.2, 84.4, 84.3]
# eeg &  85.9 & 0.802 & 77.5 & 90.7 & 41.0 & 87.2 & 84.5 & 84.3 &
# eog Acc: 79.4 K: 0.709 F1: 65.8 F1_perclass: [85.0, 9.2, 80.8, 73.3, 80.9]
# eog &  79.4 & 0.709 & 65.8 & 85.0 & 9.2 & 80.8 & 73.3 & 80.9 &
# dict_keys([120, 130, 140])
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_600e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_incomplete_100p_600e_0o.pth.tar
# -- Best Validation --
# Step: 341, No_improve: 100 ce_loss_combined : 0.416033 total : 1.446201 Acc_combined: 86.43 K_combined: 0.810 F1_combined: 77.76 F1_perclass_combined: [90.86, 39.68, 87.18, 83.72, 87.37]
# Step: 341, No_improve: 100 ce_loss_eeg : 0.410988 total : 1.446201 Acc_eeg: 85.91 K_eeg: 0.804 F1_eeg: 77.02 F1_perclass_eeg: [90.83, 37.83, 86.39, 85.87, 84.16]
# Step: 341, No_improve: 100 ce_loss_eog : 0.619180 total : 1.446201 Acc_eog: 79.78 K_eog: 0.713 F1_eog: 65.00 F1_perclass_eog: [84.89, 3.09, 80.87, 74.04, 82.09]
# --- Post Test ---
# combined Acc: 86.8 K: 0.813 F1: 77.8 F1_perclass: [91.5, 38.7, 87.8, 82.6, 88.4]
# combined &  86.8 & 0.813 & 77.8 & 91.5 & 38.7 & 87.8 & 82.6 & 88.4 &
# eeg Acc: 85.8 K: 0.801 F1: 76.8 F1_perclass: [90.5, 37.4, 86.8, 84.5, 84.7]
# eeg &  85.8 & 0.801 & 76.8 & 90.5 & 37.4 & 86.8 & 84.5 & 84.7 &
# eog Acc: 79.7 K: 0.711 F1: 64.7 F1_perclass: [84.3, 2.4, 81.2, 73.0, 82.6]
# eog &  79.7 & 0.711 & 64.7 & 84.3 & 2.4 & 81.2 & 73.0 & 82.6 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_600e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_pt_incomplete_100p_600e_0o.pth.tar
# -- Best Validation --
# Step: 362, No_improve: 100 ce_loss_combined : 0.418288 total : 1.316822 Acc_combined: 86.76 K_combined: 0.817 F1_combined: 79.03 F1_perclass_combined: [90.65, 43.32, 87.12, 85.3, 88.74]
# Step: 362, No_improve: 100 ce_loss_eeg : 0.364969 total : 1.316822 Acc_eeg: 86.48 K_eeg: 0.813 F1_eeg: 78.35 F1_perclass_eeg: [91.05, 41.72, 86.89, 85.72, 86.37]
# Step: 362, No_improve: 100 ce_loss_eog : 0.533565 total : 1.316822 Acc_eog: 80.38 K_eog: 0.724 F1_eog: 65.28 F1_perclass_eog: [84.6, 0.43, 81.29, 76.91, 83.16]
# --- Post Test ---
# combined Acc: 86.3 K: 0.808 F1: 78.2 F1_perclass: [90.3, 41.9, 87.4, 83.8, 87.5]
# combined &  86.3 & 0.808 & 78.2 & 90.3 & 41.9 & 87.4 & 83.8 & 87.5 &
# eeg Acc: 86.1 K: 0.805 F1: 77.6 F1_perclass: [90.8, 40.7, 87.2, 84.4, 84.9]
# eeg &  86.1 & 0.805 & 77.6 & 90.8 & 40.7 & 87.2 & 84.4 & 84.9 &
# eog Acc: 79.6 K: 0.709 F1: 64.4 F1_perclass: [84.3, 1.3, 81.0, 73.6, 81.7]
# eog &  79.6 & 0.709 & 64.4 & 84.2 & 1.3 & 81.0 & 73.7 & 81.7 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_600e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial2_pt_incomplete_100p_600e_0o.pth.tar
# -- Best Validation --
# Step: 211, No_improve: 100 ce_loss_combined : 0.383449 total : 1.379306 Acc_combined: 86.26 K_combined: 0.808 F1_combined: 78.14 F1_perclass_combined: [90.91, 42.08, 87.75, 83.74, 86.21]
# Step: 211, No_improve: 100 ce_loss_eeg : 0.403648 total : 1.379306 Acc_eeg: 85.12 K_eeg: 0.792 F1_eeg: 76.97 F1_perclass_eeg: [90.28, 41.44, 86.47, 85.17, 81.48]
# Step: 211, No_improve: 100 ce_loss_eog : 0.592209 total : 1.379306 Acc_eog: 78.10 K_eog: 0.691 F1_eog: 64.14 F1_perclass_eog: [84.3, 6.29, 79.63, 71.82, 78.64]
# --- Post Test ---
# combined Acc: 86.7 K: 0.813 F1: 78.5 F1_perclass: [91.2, 42.8, 88.1, 83.1, 87.5]
# combined &  86.7 & 0.813 & 78.5 & 91.2 & 42.8 & 88.1 & 83.1 & 87.5 &
# eeg Acc: 86.1 K: 0.804 F1: 77.8 F1_perclass: [90.8, 41.5, 87.3, 84.6, 84.6]
# eeg &  86.1 & 0.804 & 77.8 & 90.8 & 41.5 & 87.3 & 84.6 & 84.5 &
# eog Acc: 78.3 K: 0.693 F1: 64.1 F1_perclass: [83.6, 6.1, 80.3, 72.3, 78.3]
# eog &  78.3 & 0.693 & 64.1 & 83.6 & 6.1 & 80.3 & 72.3 & 78.3 &
# dict_keys([150, 160, 170])
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_1000e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_incomplete_100p_1000e_0o.pth.tar
# -- Best Validation --
# Step: 197, No_improve: 100 ce_loss_combined : 0.416075 total : 1.540434 Acc_combined: 85.73 K_combined: 0.801 F1_combined: 77.75 F1_perclass_combined: [90.33, 42.32, 86.62, 84.14, 85.32]
# Step: 197, No_improve: 100 ce_loss_eeg : 0.422901 total : 1.540434 Acc_eeg: 85.36 K_eeg: 0.797 F1_eeg: 76.96 F1_perclass_eeg: [90.11, 39.92, 86.04, 85.41, 83.31]
# Step: 197, No_improve: 100 ce_loss_eog : 0.701458 total : 1.540434 Acc_eog: 76.30 K_eog: 0.665 F1_eog: 61.27 F1_perclass_eog: [81.43, 0.49, 78.27, 70.82, 75.37]
# --- Post Test ---
# combined Acc: 85.5 K: 0.797 F1: 77.3 F1_perclass: [90.0, 41.5, 87.0, 83.0, 85.0]
# combined &  85.5 & 0.797 & 77.3 & 90.0 & 41.5 & 87.0 & 83.0 & 85.0 &
# eeg Acc: 85.1 K: 0.792 F1: 76.5 F1_perclass: [89.9, 39.3, 86.3, 84.0, 83.3]
# eeg &  85.1 & 0.792 & 76.5 & 89.9 & 39.3 & 86.3 & 84.0 & 83.3 &
# eog Acc: 76.0 K: 0.659 F1: 60.8 F1_perclass: [81.4, 0.6, 78.5, 68.8, 74.8]
# eog &  76.0 & 0.659 & 60.8 & 81.4 & 0.6 & 78.5 & 68.8 & 74.8 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_1000e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_pt_incomplete_100p_1000e_0o.pth.tar
# -- Best Validation --
# Step: 339, No_improve: 100 ce_loss_combined : 0.401744 total : 1.363094 Acc_combined: 86.86 K_combined: 0.818 F1_combined: 78.86 F1_perclass_combined: [90.79, 42.04, 87.25, 85.31, 88.89]
# Step: 339, No_improve: 100 ce_loss_eeg : 0.374596 total : 1.363094 Acc_eeg: 86.42 K_eeg: 0.812 F1_eeg: 77.85 F1_perclass_eeg: [90.89, 39.22, 86.85, 85.7, 86.6]
# Step: 339, No_improve: 100 ce_loss_eog : 0.586754 total : 1.363094 Acc_eog: 78.81 K_eog: 0.703 F1_eog: 63.97 F1_perclass_eog: [83.31, 0.0, 79.55, 77.44, 79.55]
# --- Post Test ---
# combined Acc: 86.5 K: 0.811 F1: 78.1 F1_perclass: [90.5, 40.6, 87.7, 84.2, 87.2]
# combined &  86.5 & 0.811 & 78.1 & 90.5 & 40.6 & 87.7 & 84.2 & 87.2 &
# eeg Acc: 86.0 K: 0.802 F1: 77.1 F1_perclass: [90.4, 38.8, 87.2, 84.4, 84.7]
# eeg &  86.0 & 0.802 & 77.1 & 90.4 & 38.8 & 87.2 & 84.4 & 84.7 &
# eog Acc: 77.9 K: 0.686 F1: 62.8 F1_perclass: [82.9, 0.0, 79.3, 73.7, 78.3]
# eog &  77.9 & 0.686 & 62.8 & 82.8 & 0.0 & 79.3 & 73.7 & 78.3 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_1000e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial2_pt_incomplete_100p_1000e_0o.pth.tar
# -- Best Validation --
# Step: 361, No_improve: 100 ce_loss_combined : 0.375801 total : 1.349381 Acc_combined: 87.13 K_combined: 0.821 F1_combined: 79.51 F1_perclass_combined: [91.48, 44.74, 88.33, 85.88, 87.11]
# Step: 361, No_improve: 100 ce_loss_eeg : 0.377589 total : 1.349381 Acc_eeg: 86.10 K_eeg: 0.806 F1_eeg: 78.58 F1_perclass_eeg: [90.99, 44.83, 87.08, 85.88, 84.13]
# Step: 361, No_improve: 100 ce_loss_eog : 0.595991 total : 1.349381 Acc_eog: 77.70 K_eog: 0.687 F1_eog: 63.31 F1_perclass_eog: [83.54, 3.06, 79.04, 72.54, 78.38]
# --- Post Test ---
# combined Acc: 87.4 K: 0.824 F1: 79.6 F1_perclass: [91.7, 44.5, 88.4, 85.0, 88.5]
# combined &  87.4 & 0.824 & 79.6 & 91.7 & 44.5 & 88.4 & 85.0 & 88.5 &
# eeg Acc: 86.9 K: 0.816 F1: 79.1 F1_perclass: [91.3, 44.3, 87.9, 85.4, 86.5]
# eeg &  86.9 & 0.816 & 79.1 & 91.3 & 44.3 & 87.9 & 85.4 & 86.5 &
# eog Acc: 78.1 K: 0.691 F1: 63.5 F1_perclass: [83.3, 3.4, 79.8, 72.6, 78.1]
# eog &  78.1 & 0.691 & 63.5 & 83.3 & 3.4 & 79.8 & 72.7 & 78.1 &
# dict_keys([180, 190, 200])
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_1500e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_incomplete_100p_1500e_0o.pth.tar
# -- Best Validation --
# Step: 663, No_improve: 200 ce_loss_combined : 0.374868 total : 1.381881 Acc_combined: 87.03 K_combined: 0.820 F1_combined: 79.41 F1_perclass_combined: [91.43, 45.29, 87.71, 84.89, 87.74]
# Step: 663, No_improve: 200 ce_loss_eeg : 0.373005 total : 1.381881 Acc_eeg: 86.95 K_eeg: 0.819 F1_eeg: 79.16 F1_perclass_eeg: [91.64, 44.51, 87.41, 86.41, 85.85]
# Step: 663, No_improve: 200 ce_loss_eog : 0.634008 total : 1.381881 Acc_eog: 78.54 K_eog: 0.698 F1_eog: 63.88 F1_perclass_eog: [83.44, 2.53, 79.75, 74.29, 79.4]
# --- Post Test ---
# combined Acc: 86.9 K: 0.817 F1: 79.0 F1_perclass: [90.9, 43.7, 88.1, 84.2, 88.3]
# combined &  86.9 & 0.817 & 79.0 & 90.9 & 43.7 & 88.0 & 84.2 & 88.3 &
# eeg Acc: 86.7 K: 0.815 F1: 78.7 F1_perclass: [91.1, 43.0, 87.7, 84.9, 86.7]
# eeg &  86.7 & 0.815 & 78.7 & 91.1 & 43.0 & 87.8 & 84.9 & 86.7 &
# eog Acc: 78.4 K: 0.695 F1: 63.7 F1_perclass: [83.1, 2.3, 80.0, 73.2, 79.7]
# eog &  78.4 & 0.695 & 63.7 & 83.1 & 2.3 & 80.0 & 73.2 & 79.7 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_1500e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_pt_incomplete_100p_1500e_0o.pth.tar
# -- Best Validation --
# Step: 664, No_improve: 200 ce_loss_combined : 0.406879 total : 1.330646 Acc_combined: 87.33 K_combined: 0.825 F1_combined: 79.64 F1_perclass_combined: [91.21, 43.97, 87.64, 85.97, 89.43]
# Step: 664, No_improve: 200 ce_loss_eeg : 0.355179 total : 1.330646 Acc_eeg: 87.26 K_eeg: 0.823 F1_eeg: 79.53 F1_perclass_eeg: [91.64, 44.18, 87.6, 86.06, 88.15]
# Step: 664, No_improve: 200 ce_loss_eog : 0.568588 total : 1.330646 Acc_eog: 79.13 K_eog: 0.706 F1_eog: 64.13 F1_perclass_eog: [83.75, 0.11, 80.09, 77.08, 79.62]
# --- Post Test ---
# combined Acc: 87.1 K: 0.818 F1: 78.6 F1_perclass: [91.1, 41.3, 88.1, 84.8, 87.8]
# combined &  87.1 & 0.818 & 78.6 & 91.1 & 41.3 & 88.1 & 84.8 & 87.8 &
# eeg Acc: 86.8 K: 0.815 F1: 78.8 F1_perclass: [91.4, 43.4, 87.9, 85.0, 86.3]
# eeg &  86.8 & 0.815 & 78.8 & 91.4 & 43.4 & 87.9 & 85.0 & 86.3 &
# eog Acc: 78.1 K: 0.688 F1: 62.9 F1_perclass: [83.3, 0.2, 79.7, 73.2, 78.2]
# eog &  78.1 & 0.688 & 62.9 & 83.3 & 0.2 & 79.7 & 73.2 & 78.2 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_1500e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial2_pt_incomplete_100p_1500e_0o.pth.tar
# -- Best Validation --
# Step: 665, No_improve: 200 ce_loss_combined : 0.356886 total : 1.326592 Acc_combined: 87.45 K_combined: 0.825 F1_combined: 79.66 F1_perclass_combined: [92.1, 44.55, 88.5, 85.35, 87.81]
# Step: 665, No_improve: 200 ce_loss_eeg : 0.369250 total : 1.326592 Acc_eeg: 86.61 K_eeg: 0.813 F1_eeg: 79.08 F1_perclass_eeg: [91.14, 45.39, 87.68, 85.72, 85.47]
# Step: 665, No_improve: 200 ce_loss_eog : 0.600455 total : 1.326592 Acc_eog: 77.46 K_eog: 0.683 F1_eog: 63.18 F1_perclass_eog: [83.17, 3.05, 78.66, 72.47, 78.57]
# --- Post Test ---
# combined Acc: 87.5 K: 0.825 F1: 78.8 F1_perclass: [91.6, 40.5, 88.5, 85.1, 88.5]
# combined &  87.5 & 0.825 & 78.8 & 91.6 & 40.5 & 88.5 & 85.1 & 88.5 &
# eeg Acc: 87.4 K: 0.824 F1: 79.5 F1_perclass: [91.8, 44.5, 88.4, 85.6, 87.3]
# eeg &  87.4 & 0.824 & 79.5 & 91.8 & 44.5 & 88.4 & 85.6 & 87.3 &
# eog Acc: 77.9 K: 0.689 F1: 63.4 F1_perclass: [83.1, 3.1, 79.5, 72.8, 78.3]
# eog &  77.9 & 0.689 & 63.4 & 83.1 & 3.1 & 79.5 & 72.8 & 78.3 &
# dict_keys([210, 220, 230])
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_2000e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_incomplete_100p_2000e_0o.pth.tar
# -- Best Validation --
# Step: 622, No_improve: 200 ce_loss_combined : 0.379257 total : 1.394081 Acc_combined: 87.10 K_combined: 0.821 F1_combined: 79.15 F1_perclass_combined: [91.44, 43.36, 87.54, 85.98, 87.41]
# Step: 622, No_improve: 200 ce_loss_eeg : 0.370467 total : 1.394081 Acc_eeg: 87.01 K_eeg: 0.819 F1_eeg: 78.82 F1_perclass_eeg: [91.57, 42.36, 87.43, 86.52, 86.21]
# Step: 622, No_improve: 200 ce_loss_eog : 0.644356 total : 1.394081 Acc_eog: 77.96 K_eog: 0.690 F1_eog: 62.95 F1_perclass_eog: [82.77, 0.71, 79.43, 73.67, 78.16]
# --- Post Test ---
# combined Acc: 87.0 K: 0.818 F1: 78.7 F1_perclass: [91.4, 42.1, 88.0, 84.4, 87.7]
# combined &  87.0 & 0.818 & 78.7 & 91.5 & 42.0 & 88.0 & 84.4 & 87.7 &
# eeg Acc: 86.8 K: 0.816 F1: 78.4 F1_perclass: [91.3, 41.2, 87.7, 84.9, 87.0]
# eeg &  86.8 & 0.816 & 78.4 & 91.3 & 41.2 & 87.7 & 84.8 & 87.0 &
# eog Acc: 77.5 K: 0.682 F1: 62.5 F1_perclass: [82.0, 0.8, 79.3, 72.2, 78.1]
# eog &  77.5 & 0.682 & 62.5 & 82.0 & 0.8 & 79.3 & 72.2 & 78.1 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_2000e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_pt_incomplete_100p_2000e_0o.pth.tar
# -- Best Validation --
# Step: 649, No_improve: 200 ce_loss_combined : 0.375569 total : 1.328789 Acc_combined: 87.36 K_combined: 0.825 F1_combined: 79.73 F1_perclass_combined: [91.21, 44.5, 87.72, 85.68, 89.57]
# Step: 649, No_improve: 200 ce_loss_eeg : 0.354004 total : 1.328789 Acc_eeg: 87.28 K_eeg: 0.823 F1_eeg: 79.43 F1_perclass_eeg: [92.04, 44.08, 87.66, 85.72, 87.64]
# Step: 649, No_improve: 200 ce_loss_eog : 0.599216 total : 1.328789 Acc_eog: 77.77 K_eog: 0.683 F1_eog: 62.28 F1_perclass_eog: [82.8, 0.0, 79.68, 70.7, 78.23]
# --- Post Test ---
# combined Acc: 86.6 K: 0.812 F1: 77.5 F1_perclass: [91.0, 37.7, 87.7, 83.9, 87.2]
# combined &  86.6 & 0.812 & 77.5 & 91.0 & 37.7 & 87.7 & 83.9 & 87.2 &
# eeg Acc: 86.9 K: 0.815 F1: 78.8 F1_perclass: [91.3, 43.3, 88.0, 84.7, 86.4]
# eeg &  86.9 & 0.815 & 78.8 & 91.3 & 43.3 & 88.0 & 84.7 & 86.3 &
# eog Acc: 77.2 K: 0.670 F1: 61.3 F1_perclass: [82.3, 0.0, 79.7, 67.8, 76.8]
# eog &  77.2 & 0.670 & 61.3 & 82.3 & 0.0 & 79.7 & 67.8 & 76.8 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_2000e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial2_pt_incomplete_100p_2000e_0o.pth.tar
# -- Best Validation --
# Step: 626, No_improve: 179 ce_loss_combined : 0.354420 total : 1.317083 Acc_combined: 87.29 K_combined: 0.823 F1_combined: 79.67 F1_perclass_combined: [91.94, 45.07, 88.34, 85.47, 87.56]
# Step: 626, No_improve: 179 ce_loss_eeg : 0.354113 total : 1.317083 Acc_eeg: 86.80 K_eeg: 0.815 F1_eeg: 79.41 F1_perclass_eeg: [91.6, 46.62, 87.84, 85.34, 85.64]
# Step: 626, No_improve: 179 ce_loss_eog : 0.608550 total : 1.317083 Acc_eog: 77.04 K_eog: 0.678 F1_eog: 62.50 F1_perclass_eog: [83.27, 1.1, 78.02, 73.24, 76.85]
# --- Post Test ---
# combined Acc: 87.6 K: 0.826 F1: 79.1 F1_perclass: [91.7, 41.7, 88.7, 84.9, 88.6]
# combined &  87.6 & 0.826 & 79.1 & 91.7 & 41.7 & 88.7 & 84.9 & 88.6 &
# eeg Acc: 87.3 K: 0.822 F1: 79.5 F1_perclass: [91.7, 45.1, 88.4, 85.1, 87.3]
# eeg &  87.3 & 0.822 & 79.5 & 91.7 & 45.1 & 88.4 & 85.1 & 87.3 &
# eog Acc: 77.1 K: 0.678 F1: 62.3 F1_perclass: [82.6, 1.0, 78.6, 72.8, 76.4]
# eog &  77.1 & 0.678 & 62.3 & 82.6 & 1.0 & 78.6 & 72.8 & 76.4 &
# dict_keys([240, 250, 260])
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_0e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial2_pt_incomplete_100p_0e_0o.pth.tar
# -- Best Validation --
# Step: 60, No_improve: 336 ce_loss_combined : 0.392099 total : 1.410688 Acc_combined: 85.49 K_combined: 0.797 F1_combined: 76.35 F1_perclass_combined: [89.92, 35.7, 86.67, 83.65, 85.8]
# Step: 60, No_improve: 336 ce_loss_eeg : 0.476924 total : 1.410688 Acc_eeg: 82.70 K_eeg: 0.758 F1_eeg: 72.89 F1_perclass_eeg: [88.24, 30.97, 84.13, 83.76, 77.34]
# Step: 60, No_improve: 336 ce_loss_eog : 0.541665 total : 1.410688 Acc_eog: 79.64 K_eog: 0.714 F1_eog: 67.31 F1_perclass_eog: [85.92, 14.23, 80.28, 73.11, 83.03]
# --- Post Test ---
# combined Acc: 86.0 K: 0.803 F1: 76.3 F1_perclass: [90.4, 34.1, 87.2, 83.5, 86.6]
# combined &  86.0 & 0.803 & 76.3 & 90.4 & 34.1 & 87.2 & 83.5 & 86.6 &
# eeg Acc: 83.0 K: 0.761 F1: 72.7 F1_perclass: [88.0, 29.6, 84.8, 82.6, 78.4]
# eeg &  83.0 & 0.761 & 72.7 & 88.0 & 29.6 & 84.8 & 82.6 & 78.4 &
# eog Acc: 79.9 K: 0.718 F1: 67.3 F1_perclass: [85.4, 13.9, 81.0, 73.4, 82.9]
# eog &  79.9 & 0.718 & 67.3 & 85.4 & 13.9 & 81.0 & 73.4 & 82.9 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_0e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_pt_incomplete_100p_0e_0o.pth.tar
# -- Best Validation --
# Step: 64, No_improve: 332 ce_loss_combined : 0.438388 total : 1.456262 Acc_combined: 85.74 K_combined: 0.803 F1_combined: 77.01 F1_perclass_combined: [90.43, 38.09, 86.47, 82.26, 87.8]
# Step: 64, No_improve: 332 ce_loss_eeg : 0.516627 total : 1.456262 Acc_eeg: 83.97 K_eeg: 0.778 F1_eeg: 74.24 F1_perclass_eeg: [89.33, 31.97, 84.78, 83.81, 81.32]
# Step: 64, No_improve: 332 ce_loss_eog : 0.501247 total : 1.456262 Acc_eog: 81.54 K_eog: 0.741 F1_eog: 68.80 F1_perclass_eog: [86.56, 14.02, 82.27, 76.28, 84.84]
# --- Post Test ---
# combined Acc: 85.3 K: 0.794 F1: 76.7 F1_perclass: [89.7, 39.1, 86.6, 81.5, 86.6]
# combined &  85.3 & 0.794 & 76.7 & 89.7 & 39.1 & 86.6 & 81.5 & 86.6 &
# eeg Acc: 83.1 K: 0.764 F1: 73.4 F1_perclass: [88.6, 32.8, 84.6, 82.4, 78.8]
# eeg &  83.1 & 0.764 & 73.4 & 88.6 & 32.8 & 84.6 & 82.4 & 78.8 &
# eog Acc: 80.5 K: 0.723 F1: 67.7 F1_perclass: [85.6, 14.7, 81.8, 73.1, 83.5]
# eog &  80.5 & 0.723 & 67.7 & 85.6 & 14.7 & 81.8 & 73.1 & 83.5 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_0e_0o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_incomplete_100p_0e_0o.pth.tar
# -- Best Validation --
# Step: 58, No_improve: 341 ce_loss_combined : 0.427301 total : 1.542237 Acc_combined: 85.33 K_combined: 0.796 F1_combined: 76.95 F1_perclass_combined: [90.06, 39.18, 86.06, 82.68, 86.77]
# Step: 58, No_improve: 341 ce_loss_eeg : 0.526975 total : 1.542237 Acc_eeg: 81.97 K_eeg: 0.747 F1_eeg: 72.70 F1_perclass_eeg: [87.42, 34.43, 83.6, 82.37, 75.68]
# Step: 58, No_improve: 341 ce_loss_eog : 0.587960 total : 1.542237 Acc_eog: 80.39 K_eog: 0.722 F1_eog: 65.93 F1_perclass_eog: [85.83, 5.27, 81.39, 73.17, 83.97]
# --- Post Test ---
# combined Acc: 85.2 K: 0.792 F1: 76.4 F1_perclass: [90.5, 37.6, 86.1, 81.1, 86.8]
# combined &  85.2 & 0.792 & 76.4 & 90.5 & 37.6 & 86.1 & 81.0 & 86.8 &
# eeg Acc: 81.3 K: 0.736 F1: 72.0 F1_perclass: [87.2, 34.3, 83.5, 81.0, 74.1]
# eeg &  81.3 & 0.736 & 72.0 & 87.2 & 34.3 & 83.5 & 81.0 & 74.1 &
# eog Acc: 80.3 K: 0.719 F1: 65.8 F1_perclass: [85.1, 5.7, 81.7, 72.3, 84.0]
# eog &  80.3 & 0.719 & 65.8 & 85.1 & 5.7 & 81.7 & 72.2 & 84.0 &
# dict_keys([0, 10, 20])
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_0e_50o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_incomplete_100p_0e_50o.pth.tar
# -- Best Validation --
# Step: 73, No_improve: 325 ce_loss_combined : 0.427442 total : 1.458180 Acc_combined: 85.67 K_combined: 0.801 F1_combined: 76.70 F1_perclass_combined: [90.21, 35.9, 86.25, 83.49, 87.64]
# Step: 73, No_improve: 325 ce_loss_eeg : 0.496500 total : 1.458180 Acc_eeg: 83.05 K_eeg: 0.765 F1_eeg: 73.43 F1_perclass_eeg: [88.75, 31.8, 83.71, 83.56, 79.32]
# Step: 73, No_improve: 325 ce_loss_eog : 0.534238 total : 1.458180 Acc_eog: 81.52 K_eog: 0.741 F1_eog: 69.07 F1_perclass_eog: [86.87, 14.65, 81.79, 77.02, 85.02]
# --- Post Test ---
# combined Acc: 86.1 K: 0.805 F1: 77.2 F1_perclass: [90.7, 36.8, 86.8, 83.1, 88.6]
# combined &  86.1 & 0.805 & 77.2 & 90.7 & 36.8 & 86.8 & 83.1 & 88.6 &
# eeg Acc: 82.5 K: 0.757 F1: 73.0 F1_perclass: [88.4, 32.2, 83.7, 82.1, 78.7]
# eeg &  82.5 & 0.757 & 73.0 & 88.4 & 32.2 & 83.8 & 82.1 & 78.7 &
# eog Acc: 80.9 K: 0.732 F1: 68.3 F1_perclass: [85.7, 13.1, 81.4, 75.4, 85.6]
# eog &  80.9 & 0.732 & 68.3 & 85.7 & 13.1 & 81.4 & 75.4 & 85.6 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_0e_50o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_pt_incomplete_100p_0e_50o.pth.tar
# -- Best Validation --
# Step: 95, No_improve: 50 ce_loss_combined : 0.362603 total : 1.356456 Acc_combined: 87.19 K_combined: 0.822 F1_combined: 77.85 F1_perclass_combined: [92.28, 36.41, 87.78, 84.51, 88.3]
# Step: 95, No_improve: 50 ce_loss_eeg : 0.529399 total : 1.356456 Acc_eeg: 83.85 K_eeg: 0.776 F1_eeg: 73.62 F1_perclass_eeg: [89.28, 29.32, 84.67, 83.68, 81.13]
# Step: 95, No_improve: 50 ce_loss_eog : 0.464454 total : 1.356456 Acc_eog: 82.74 K_eog: 0.759 F1_eog: 70.91 F1_perclass_eog: [88.02, 18.29, 82.83, 78.61, 86.78]
# --- Post Test ---
# combined Acc: 86.2 K: 0.805 F1: 77.1 F1_perclass: [90.5, 37.4, 87.3, 83.0, 87.5]
# combined &  86.2 & 0.805 & 77.1 & 90.5 & 37.4 & 87.3 & 83.0 & 87.5 &
# eeg Acc: 83.1 K: 0.762 F1: 72.9 F1_perclass: [88.5, 30.3, 84.6, 82.7, 78.6]
# eeg &  83.1 & 0.762 & 72.9 & 88.5 & 30.3 & 84.6 & 82.7 & 78.6 &
# eog Acc: 81.4 K: 0.737 F1: 69.5 F1_perclass: [86.6, 18.9, 82.5, 74.8, 84.8]
# eog &  81.4 & 0.737 & 69.5 & 86.6 & 18.9 & 82.5 & 74.8 & 84.8 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_0e_50o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial2_pt_incomplete_100p_0e_50o.pth.tar
# -- Best Validation --
# Step: 94, No_improve: 50 ce_loss_combined : 0.376221 total : 1.371958 Acc_combined: 86.48 K_combined: 0.811 F1_combined: 78.41 F1_perclass_combined: [91.06, 41.56, 87.63, 83.87, 87.95]
# Step: 94, No_improve: 50 ce_loss_eeg : 0.484288 total : 1.371958 Acc_eeg: 83.05 K_eeg: 0.763 F1_eeg: 74.06 F1_perclass_eeg: [88.45, 35.03, 84.57, 83.67, 78.59]
# Step: 94, No_improve: 50 ce_loss_eog : 0.511449 total : 1.371958 Acc_eog: 80.77 K_eog: 0.730 F1_eog: 69.57 F1_perclass_eog: [87.06, 21.09, 81.43, 73.35, 84.94]
# --- Post Test ---
# combined Acc: 86.8 K: 0.815 F1: 78.2 F1_perclass: [91.3, 39.6, 87.9, 84.0, 88.3]
# combined &  86.8 & 0.815 & 78.2 & 91.3 & 39.6 & 87.8 & 84.0 & 88.3 &
# eeg Acc: 83.6 K: 0.769 F1: 74.3 F1_perclass: [88.8, 34.8, 85.3, 82.8, 79.8]
# ...
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_pt_incomplete_100p_400e_400o.pth.tar
# -- Best Validation --
# Step: 371, No_improve: 100 ce_loss_combined : 0.326674 total : 1.149165 Acc_combined: 87.63 K_combined: 0.828 F1_combined: 79.45 F1_perclass_combined: [92.12, 42.16, 87.98, 85.32, 89.65]
# Step: 371, No_improve: 100 ce_loss_eeg : 0.394324 total : 1.149165 Acc_eeg: 85.85 K_eeg: 0.804 F1_eeg: 77.59 F1_perclass_eeg: [90.62, 40.48, 86.36, 85.28, 85.22]
# Step: 371, No_improve: 100 ce_loss_eog : 0.428167 total : 1.149165 Acc_eog: 83.90 K_eog: 0.775 F1_eog: 71.84 F1_perclass_eog: [88.86, 18.42, 84.02, 79.38, 88.51]
# --- Post Test ---
# combined Acc: 86.8 K: 0.815 F1: 78.5 F1_perclass: [90.9, 41.4, 87.8, 83.7, 88.6]
# combined &  86.8 & 0.815 & 78.5 & 90.9 & 41.4 & 87.8 & 83.7 & 88.6 &
# eeg Acc: 85.1 K: 0.791 F1: 76.4 F1_perclass: [90.0, 39.2, 86.4, 83.9, 82.5]
# eeg &  85.1 & 0.791 & 76.4 & 90.0 & 39.2 & 86.4 & 83.9 & 82.5 &
# eog Acc: 82.5 K: 0.752 F1: 70.4 F1_perclass: [87.7, 18.8, 83.3, 75.5, 86.6]
# eog &  82.5 & 0.752 & 70.4 & 87.7 & 18.8 & 83.3 & 75.5 & 86.6 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_400e_400o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial2_pt_incomplete_100p_400e_400o.pth.tar
# -- Best Validation --
# Step: 375, No_improve: 100 ce_loss_combined : 0.344989 total : 1.242286 Acc_combined: 87.21 K_combined: 0.821 F1_combined: 78.74 F1_perclass_combined: [91.71, 41.16, 88.55, 84.2, 88.1]
# Step: 375, No_improve: 100 ce_loss_eeg : 0.418577 total : 1.242286 Acc_eeg: 84.95 K_eeg: 0.789 F1_eeg: 75.91 F1_perclass_eeg: [89.98, 36.7, 86.32, 84.88, 81.7]
# Step: 375, No_improve: 100 ce_loss_eog : 0.478721 total : 1.242286 Acc_eog: 81.94 K_eog: 0.745 F1_eog: 70.80 F1_perclass_eog: [88.21, 22.89, 82.53, 74.17, 86.22]
# --- Post Test ---
# combined Acc: 87.7 K: 0.826 F1: 79.0 F1_perclass: [92.2, 40.4, 88.6, 84.1, 89.4]
# combined &  87.7 & 0.826 & 79.0 & 92.2 & 40.4 & 88.6 & 84.1 & 89.4 &
# eeg Acc: 86.0 K: 0.802 F1: 76.8 F1_perclass: [90.7, 37.2, 87.2, 84.5, 84.5]
# eeg &  86.0 & 0.802 & 76.8 & 90.7 & 37.2 & 87.2 & 84.5 & 84.5 &
# eog Acc: 83.1 K: 0.761 F1: 71.6 F1_perclass: [88.7, 22.8, 84.0, 75.8, 86.9]
# eog &  83.1 & 0.761 & 71.6 & 88.7 & 22.8 & 84.0 & 75.8 & 86.9 &
# dict_keys([120, 130, 140])
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_600e_600o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_incomplete_100p_600e_600o.pth.tar
# -- Best Validation --
# Step: 212, No_improve: 100 ce_loss_combined : 0.388659 total : 1.358036 Acc_combined: 86.08 K_combined: 0.805 F1_combined: 77.80 F1_perclass_combined: [90.65, 40.93, 86.86, 82.62, 87.93]
# Step: 212, No_improve: 100 ce_loss_eeg : 0.463685 total : 1.358036 Acc_eeg: 84.12 K_eeg: 0.779 F1_eeg: 75.28 F1_perclass_eeg: [89.16, 37.35, 85.08, 84.3, 80.53]
# Step: 212, No_improve: 100 ce_loss_eog : 0.505692 total : 1.358036 Acc_eog: 81.64 K_eog: 0.741 F1_eog: 69.63 F1_perclass_eog: [86.77, 17.9, 82.46, 75.36, 85.64]
# --- Post Test ---
# combined Acc: 86.7 K: 0.812 F1: 78.0 F1_perclass: [91.3, 39.5, 87.6, 82.8, 88.8]
# combined &  86.7 & 0.812 & 78.0 & 91.3 & 39.5 & 87.6 & 82.8 & 88.8 &
# eeg Acc: 83.7 K: 0.772 F1: 74.9 F1_perclass: [89.0, 37.2, 85.1, 83.2, 80.0]
# eeg &  83.7 & 0.772 & 74.9 & 89.0 & 37.2 & 85.1 & 83.2 & 80.0 &
# eog Acc: 82.0 K: 0.745 F1: 69.6 F1_perclass: [86.9, 17.0, 83.1, 74.6, 86.3]
# eog &  82.0 & 0.745 & 69.6 & 86.9 & 17.0 & 83.1 & 74.6 & 86.3 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_600e_600o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_pt_incomplete_100p_600e_600o.pth.tar
# -- Best Validation --
# Step: 382, No_improve: 100 ce_loss_combined : 0.323015 total : 1.148004 Acc_combined: 88.11 K_combined: 0.835 F1_combined: 79.45 F1_perclass_combined: [93.24, 40.29, 88.32, 85.46, 89.92]
# Step: 382, No_improve: 100 ce_loss_eeg : 0.399085 total : 1.148004 Acc_eeg: 85.71 K_eeg: 0.802 F1_eeg: 77.12 F1_perclass_eeg: [90.37, 38.92, 86.35, 85.39, 84.56]
# Step: 382, No_improve: 100 ce_loss_eog : 0.425905 total : 1.148004 Acc_eog: 83.94 K_eog: 0.775 F1_eog: 72.16 F1_perclass_eog: [89.03, 19.94, 84.04, 79.34, 88.45]
# --- Post Test ---
# combined Acc: 87.4 K: 0.823 F1: 78.7 F1_perclass: [91.9, 40.0, 88.3, 84.1, 89.1]
# combined &  87.4 & 0.823 & 78.7 & 91.9 & 40.0 & 88.2 & 84.1 & 89.1 &
# eeg Acc: 85.2 K: 0.792 F1: 76.2 F1_perclass: [89.9, 38.0, 86.6, 84.0, 82.6]
# eeg &  85.2 & 0.792 & 76.2 & 89.9 & 38.0 & 86.6 & 84.0 & 82.6 &
# eog Acc: 82.7 K: 0.756 F1: 70.9 F1_perclass: [88.0, 20.7, 83.6, 75.6, 86.6]
# eog &  82.7 & 0.756 & 70.9 & 88.0 & 20.7 & 83.7 & 75.6 & 86.6 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_600e_600o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial2_pt_incomplete_100p_600e_600o.pth.tar
# -- Best Validation --
# Step: 366, No_improve: 100 ce_loss_combined : 0.337197 total : 1.224097 Acc_combined: 87.36 K_combined: 0.823 F1_combined: 79.09 F1_perclass_combined: [91.85, 41.91, 88.59, 84.73, 88.35]
# Step: 366, No_improve: 100 ce_loss_eeg : 0.412784 total : 1.224097 Acc_eeg: 84.86 K_eeg: 0.788 F1_eeg: 75.84 F1_perclass_eeg: [90.18, 36.61, 86.07, 85.19, 81.13]
# Step: 366, No_improve: 100 ce_loss_eog : 0.474116 total : 1.224097 Acc_eog: 82.02 K_eog: 0.747 F1_eog: 70.46 F1_perclass_eog: [88.14, 20.45, 82.65, 74.76, 86.31]
# --- Post Test ---
# combined Acc: 87.6 K: 0.825 F1: 79.1 F1_perclass: [92.0, 41.3, 88.6, 84.3, 89.2]
# combined &  87.6 & 0.825 & 79.1 & 92.0 & 41.3 & 88.6 & 84.3 & 89.2 &
# eeg Acc: 85.7 K: 0.798 F1: 76.4 F1_perclass: [90.4, 36.6, 86.9, 84.6, 83.6]
# eeg &  85.7 & 0.798 & 76.4 & 90.4 & 36.6 & 86.9 & 84.6 & 83.6 &
# eog Acc: 83.1 K: 0.760 F1: 71.4 F1_perclass: [88.7, 21.3, 83.8, 76.0, 87.1]
# eog &  83.1 & 0.760 & 71.4 & 88.7 & 21.3 & 83.8 & 76.0 & 87.1 &
# dict_keys([150, 160, 170])
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_1000e_1000o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_incomplete_100p_1000e_1000o.pth.tar
# -- Best Validation --
# Step: 377, No_improve: 100 ce_loss_combined : 0.367022 total : 1.280556 Acc_combined: 87.06 K_combined: 0.820 F1_combined: 79.22 F1_perclass_combined: [91.53, 43.84, 87.55, 84.26, 88.93]
# Step: 377, No_improve: 100 ce_loss_eeg : 0.453637 total : 1.280556 Acc_eeg: 85.11 K_eeg: 0.793 F1_eeg: 76.48 F1_perclass_eeg: [89.87, 39.21, 86.12, 84.53, 82.68]
# Step: 377, No_improve: 100 ce_loss_eog : 0.459897 total : 1.280556 Acc_eog: 83.10 K_eog: 0.763 F1_eog: 71.88 F1_perclass_eog: [88.97, 22.77, 83.49, 77.01, 87.17]
# --- Post Test ---
# combined Acc: 87.3 K: 0.822 F1: 79.0 F1_perclass: [91.8, 41.5, 88.2, 84.0, 89.6]
# combined &  87.3 & 0.822 & 79.0 & 91.8 & 41.5 & 88.2 & 84.0 & 89.6 &
# eeg Acc: 84.8 K: 0.787 F1: 76.2 F1_perclass: [89.7, 39.1, 86.1, 83.7, 82.3]
# eeg &  84.8 & 0.787 & 76.2 & 89.7 & 39.1 & 86.2 & 83.7 & 82.3 &
# eog Acc: 83.1 K: 0.762 F1: 71.8 F1_perclass: [88.3, 23.0, 83.9, 76.4, 87.4]
# eog &  83.1 & 0.762 & 71.8 & 88.3 & 23.0 & 83.9 & 76.4 & 87.4 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_1000e_1000o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_pt_incomplete_100p_1000e_1000o.pth.tar
# -- Best Validation --
# Step: 362, No_improve: 100 ce_loss_combined : 0.336046 total : 1.178856 Acc_combined: 87.43 K_combined: 0.826 F1_combined: 79.87 F1_perclass_combined: [91.89, 44.76, 87.77, 85.11, 89.81]
# Step: 362, No_improve: 100 ce_loss_eeg : 0.416145 total : 1.178856 Acc_eeg: 85.25 K_eeg: 0.796 F1_eeg: 77.10 F1_perclass_eeg: [90.18, 40.54, 85.93, 84.97, 83.88]
# Step: 362, No_improve: 100 ce_loss_eog : 0.426664 total : 1.178856 Acc_eog: 83.82 K_eog: 0.773 F1_eog: 72.78 F1_perclass_eog: [89.12, 24.26, 84.18, 77.59, 88.73]
# --- Post Test ---
# combined Acc: 86.9 K: 0.817 F1: 79.1 F1_perclass: [91.1, 43.8, 88.0, 83.7, 88.9]
# combined &  86.9 & 0.817 & 79.1 & 91.1 & 43.9 & 88.0 & 83.7 & 88.9 &
# eeg Acc: 84.7 K: 0.786 F1: 76.3 F1_perclass: [89.7, 40.2, 86.2, 83.7, 81.7]
# eeg &  84.7 & 0.786 & 76.3 & 89.7 & 40.2 & 86.2 & 83.7 & 81.7 &
# eog Acc: 82.8 K: 0.756 F1: 71.7 F1_perclass: [88.4, 25.6, 84.0, 74.1, 86.7]
# eog &  82.8 & 0.756 & 71.7 & 88.4 & 25.6 & 84.0 & 74.1 & 86.8 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_1000e_1000o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial2_pt_incomplete_100p_1000e_1000o.pth.tar
# -- Best Validation --
# Step: 372, No_improve: 100 ce_loss_combined : 0.347179 total : 1.235285 Acc_combined: 87.22 K_combined: 0.821 F1_combined: 78.69 F1_perclass_combined: [91.6, 40.59, 88.45, 84.36, 88.44]
# Step: 372, No_improve: 100 ce_loss_eeg : 0.419555 total : 1.235285 Acc_eeg: 84.69 K_eeg: 0.786 F1_eeg: 76.22 F1_perclass_eeg: [89.83, 39.44, 86.08, 84.89, 80.86]
# Step: 372, No_improve: 100 ce_loss_eog : 0.468551 total : 1.235285 Acc_eog: 82.27 K_eog: 0.750 F1_eog: 70.58 F1_perclass_eog: [88.75, 20.53, 82.86, 74.07, 86.69]
# --- Post Test ---
# combined Acc: 87.6 K: 0.826 F1: 79.0 F1_perclass: [92.1, 40.5, 88.6, 84.5, 89.2]
# combined &  87.6 & 0.826 & 79.0 & 92.1 & 40.5 & 88.6 & 84.5 & 89.2 &
# eeg Acc: 85.6 K: 0.797 F1: 76.8 F1_perclass: [90.5, 39.2, 86.8, 84.3, 83.2]
# eeg &  85.6 & 0.797 & 76.8 & 90.5 & 39.2 & 86.8 & 84.3 & 83.2 &
# eog Acc: 83.4 K: 0.764 F1: 71.5 F1_perclass: [89.1, 20.9, 84.2, 75.7, 87.4]
# eog &  83.4 & 0.764 & 71.5 & 89.1 & 20.9 & 84.2 & 75.7 & 87.4 &
# dict_keys([180, 190, 200])
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_incomplete_100p_1500e_1500o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_incomplete_100p_1500e_1500o.pth.tar
# -- Best Validation --
# Step: 648, No_improve: 200 ce_loss_combined : 0.363964 total : 1.209838 Acc_combined: 87.30 K_combined: 0.823 F1_combined: 79.27 F1_perclass_combined: [92.0, 42.9, 87.81, 84.98, 88.64]
# Step: 648, No_improve: 200 ce_loss_eeg : 0.405383 total : 1.209838 Acc_eeg: 85.87 K_eeg: 0.803 F1_eeg: 77.68 F1_perclass_eeg: [90.63, 42.02, 86.7, 85.79, 83.24]
# Step: 648, No_improve: 200 ce_loss_eog : 0.440491 total : 1.209838 Acc_eog: 83.80 K_eog: 0.774 F1_eog: 73.24 F1_perclass_eog: [90.0, 26.23, 83.81, 78.54, 87.64]
# --- Post Test ---
# combined Acc: 87.5 K: 0.824 F1: 79.2 F1_perclass: [91.9, 41.2, 88.2, 84.7, 89.8]
# combined &  87.5 & 0.824 & 79.2 & 91.9 & 41.2 & 88.2 & 84.7 & 89.8 &
# eeg Acc: 85.4 K: 0.796 F1: 77.2 F1_perclass: [90.1, 41.3, 86.7, 84.3, 83.5]
# eeg &  85.4 & 0.796 & 77.2 & 90.1 & 41.3 & 86.7 & 84.3 & 83.5 &
# eog Acc: 83.5 K: 0.769 F1: 72.7 F1_perclass: [89.3, 25.2, 83.8, 77.3, 88.1]
# eog &  83.5 & 0.769 & 72.7 & 89.3 & 25.2 & 83.8 & 77.3 & 88.1 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial1_pt_incomplete_100p_1500e_1500o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial1_pt_incomplete_100p_1500e_1500o.pth.tar
# -- Best Validation --
# Step: 699, No_improve: 200 ce_loss_combined : 0.322552 total : 1.111882 Acc_combined: 87.92 K_combined: 0.832 F1_combined: 78.94 F1_perclass_combined: [92.71, 38.41, 88.23, 85.74, 89.61]
# Step: 699, No_improve: 200 ce_loss_eeg : 0.388120 total : 1.111882 Acc_eeg: 86.10 K_eeg: 0.808 F1_eeg: 77.66 F1_perclass_eeg: [90.75, 39.75, 86.56, 85.55, 85.69]
# Step: 699, No_improve: 200 ce_loss_eog : 0.401210 total : 1.111882 Acc_eog: 84.78 K_eog: 0.787 F1_eog: 73.48 F1_perclass_eog: [90.53, 23.58, 84.77, 79.74, 88.76]
# --- Post Test ---
# combined Acc: 87.4 K: 0.822 F1: 78.4 F1_perclass: [91.7, 38.7, 88.3, 84.4, 88.7]
# combined &  87.4 & 0.822 & 78.4 & 91.7 & 38.7 & 88.3 & 84.4 & 88.7 &
# eeg Acc: 85.6 K: 0.799 F1: 76.9 F1_perclass: [90.4, 39.2, 87.0, 84.5, 83.5]
# eeg &  85.6 & 0.799 & 76.9 & 90.4 & 39.2 & 87.0 & 84.5 & 83.5 &
# eog Acc: 83.8 K: 0.771 F1: 72.5 F1_perclass: [89.6, 24.7, 84.6, 76.0, 87.8]
# eog &  83.8 & 0.771 & 72.5 & 89.6 & 24.7 & 84.6 & 76.0 & 87.8 &
# Loading config from ./configs/shhs/multi_modal/eeg_eog/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_nopos_nonsharedpreds_drop03_aligninner_trial2_pt_incomplete_100p_1500e_1500o.json
# Loading from /esat/smcdata/users/kkontras/Image_Dataset/no_backup/data/2021_data/shhs1/multi_modal/paper_models/fourier_transformer_eeg_eog_mat_BLIP_al01_shared_b16_freetrain_rpos_nopos_nonsharedpreds_drop03_align_inner_trial2_pt_incomplete_100p_1500e_1500o.pth.tar
# -- Best Validation --
# Step: 704, No_improve: 200 ce_loss_combined : 0.330244 total : 1.163803 Acc_combined: 87.64 K_combined: 0.827 F1_combined: 79.02 F1_perclass_combined: [91.98, 40.37, 88.88, 85.12, 88.76]
# Step: 704, No_improve: 200 ce_loss_eeg : 0.388373 total : 1.163803 Acc_eeg: 85.81 K_eeg: 0.802 F1_eeg: 77.36 F1_perclass_eeg: [90.89, 40.18, 87.03, 85.59, 83.11]
# Step: 704, No_improve: 200 ce_loss_eog : 0.445186 total : 1.163803 Acc_eog: 83.16 K_eog: 0.763 F1_eog: 72.06 F1_perclass_eog: [89.71, 24.13, 83.6, 75.19, 87.66]
# --- Post Test ---
# combined Acc: 87.9 K: 0.830 F1: 79.2 F1_perclass: [92.3, 40.5, 88.9, 84.7, 89.6]
# combined &  87.9 & 0.830 & 79.2 & 92.3 & 40.5 & 88.9 & 84.7 & 89.6 &
# eeg Acc: 86.4 K: 0.810 F1: 77.7 F1_perclass: [91.2, 39.8, 87.6, 85.1, 85.0]
# eeg &  86.4 & 0.810 & 77.7 & 91.2 & 39.8 & 87.6 & 85.0 & 85.0 &
# eog Acc: 84.1 K: 0.776 F1: 72.9 F1_perclass: [90.1, 24.9, 84.8, 76.5, 88.3]
# eog &  84.1 & 0.776 & 72.9 & 90.0 & 24.9 & 84.8 & 76.5 & 88.3 &
# dict_keys([210, 220, 230])

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

def plot_signle_line(x, y, yerr, label, color):
    plt.fill_between(x, y-yerr, y+yerr, alpha=0.5, color=color)
    plt.plot(x, y, color=color, label=label)
    plt.scatter(x, y, color=color)

title_fonts = 34
axis_fonts = 34

fig = plt.figure(figsize=(14,6))

# fig.suptitle("Training with 100 EEG-EOG patients and", fontsize = title_fonts)
ax = plt.subplot(111)
x= np.array([  0, 50,  100,  200, 400,  600, 1000, 1500])
plot_signle_line( x, both_mm, both_mm_std, "Multimodal", "black")
plot_signle_line( x, both_eeg, both_eeg_std, "EEG", "blue")
plot_signle_line( x, both_eog, both_eog_std, "EOG", "orange")
# plt.legend(fontsize=12, frameon=False, ncol=3,  bbox_to_anchor=(0.28, 0.88))
# plt.xlabel("Extra Unimodal EEG and EOG Patients", fontsize=axis_fonts, labelpad=16)
plt.ylabel("Cohens Kappa", fontsize=axis_fonts, labelpad=8)
plt.xticks([0, 100, 200, 400, 600, 1000, 1500, 2000], fontsize = 21)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.yticks([0.70,0.75,0.80,0.85 ], fontsize = 21)
plt.xlim(-100,1600)
plt.ylim(0.65,0.85)
plt.tight_layout()
# plt.title("Unimodal EEG, EOG", fontsize=title_fonts)
plt.savefig("./incomplete_100c_1500e_1500o.svg")
plt.show()

fig = plt.figure(figsize=(14,6))
ax = plt.subplot(111)
x = np.array([0, 50, 100, 200, 400, 600, 1000, 1500, 2000])
plot_signle_line(x, a_mm, a_mm_std, "Multimodal", "black")
plot_signle_line(x, a_eeg, a_eeg_std, "EEG", "blue")
plot_signle_line(x, a_eog, a_eog_std, "EOG", "orange")
# leg = plt.legend(fontsize=title_fonts, frameon=False, ncol=3, bbox_to_anchor=(1.0, -0.25))
# leg = plt.legend(fontsize=14, frameon=False, ncol=3, bbox_to_anchor=(0.84, 1.2))
# for line in leg.get_lines():
#     line.set_linewidth(4.0)

# plt.xlabel("Extra Unimodal EEG Patients", fontsize=axis_fonts, labelpad=16)
# plt.ylabel("Cohens Kappa", fontsize=axis_fonts, labelpad=8)
plt.xticks([0, 100, 200, 400, 600, 1000, 1500, 2000], fontsize = 21)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.yticks([0.70,0.75,0.80,0.85 ], fontsize = 21)
plt.xlim(-100,2100)
plt.ylim(0.65,0.85)
plt.tight_layout()
# plt.title("Unimodal EEG, EOG", fontsize=title_fonts)
plt.savefig("./incomplete_100c_1500e_0o.svg")
plt.show()

fig = plt.figure(figsize=(14,6))
ax = plt.subplot(111)
x = np.array([0, 50, 100, 200, 400, 600, 1000, 1500, 2000])
plot_signle_line(x, b_mm, b_mm_std, "Multimodal", "black")
plot_signle_line(x, b_eeg, b_eeg_std, "EEG", "blue")
plot_signle_line(x, b_eog, b_eog_std, "EOG", "orange")
leg = plt.legend(fontsize=title_fonts-2, frameon=False, ncol=3, bbox_to_anchor=(0.068, 0.88))
# leg = plt.legend(fontsize=14, frameon=False, ncol=3, bbox_to_anchor=(0.84, 1.2))
for line in leg.get_lines():
    line.set_linewidth(4.0)

# plt.xlabel("Extra Unimodal EOG Patients", fontsize=axis_fonts, labelpad=16)
# plt.ylabel("Cohens Kappa", fontsize=axis_fonts, labelpad=8)
plt.xticks([0, 100, 200, 400, 600, 1000, 1500, 2000], fontsize = 21)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.yticks([0.70,0.75,0.80,0.85 ], fontsize = 21)
plt.xlim(-100,2100)
plt.ylim(0.65,0.85)
plt.tight_layout()
# plt.title("Unimodal EEG, EOG", fontsize=title_fonts)
plt.savefig("./incomplete_100c_0e_1500o.svg")
plt.show()

# ax = plt.subplot(133)
# x = np.array([0, 50, 100, 200, 400, 600, 1000, 1500, 2000])
# plot_signle_line(x, b_eeg, b_eeg_std, "EEG", "blue")
# plot_signle_line(x, b_eog, b_eog_std, "EOG", "orange")
# plot_signle_line(x, b_mm, b_mm_std, "Multimodal", "black")
# # plt.legend(fontsize=12, frameon=False, ncol=3, bbox_to_anchor=(0.28, 0.88))
# plt.xlabel("Extra Single-Modality EOG Patients", fontsize=axis_fonts, labelpad=16)
# plt.ylabel("Cohens Kappa", fontsize=axis_fonts, labelpad=8)
# plt.xticks(x, fontsize=11)
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
# plt.yticks([0.65, 0.70, 0.75, 0.80, 0.85], fontsize=axis_fonts)
# plt.xlim(-100, 2100)
# plt.ylim(0.65, 0.85)
# plt.title("Unimodal EOG", fontsize=title_fonts)
# plt.tight_layout()
# plt.subplots_adjust(wspace=0.18, hspace=0)
# plt.savefig("./incomplete_100c.svg")
# plt.show()

# %%
x
# Out:
# array([   0,   50,  100,  200,  400,  600, 1000, 1500])

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

eeg, eog, mm = np.array(eeg), np.array(eog), np.array(mm)
eeg_std, eog_std, mm_std = np.array(eeg_std), np.array(eog_std), np.array(mm_std)


def plot_signle_line(x, y, yerr, label, color):
    plt.plot(x, y, color=color, label=label)
    plt.scatter(x, y, color=color)
    plt.fill_between(x, y - yerr, y + yerr, alpha=0.5)


plt.figure(figsize=(14, 6))
ax = plt.subplot(111)
x = np.array([0, 50, 100, 200, 400, 600, 1000, 1500, 2000])
plot_signle_line(x, eeg, eeg_std, "EEG", "blue")
plot_signle_line(x, eog, eog_std, "EOG", "orange")
plot_signle_line(x, mm, mm_std, "Multimodal", "black")
plt.legend(fontsize=12, frameon=False, ncol=3, bbox_to_anchor=(0.28, 0.88))
plt.xlabel("Extra Single-Modality EEG Patients", fontsize=12)
plt.ylabel("Cohens Kappa", fontsize=12)
plt.xticks(x, fontsize=8)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.yticks([0.65, 0.70, 0.75, 0.80, 0.85], fontsize=8)
plt.xlim(-100, 2100)
plt.ylim(0.65, 0.85)
plt.title("Training with 100 EEG-EOG patients and EEG unimodal ones", fontsize=14)
plt.savefig("./incomplete_100c_2000e_0o.svg")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_789588/2503225198.py in <module>
#      16 ax = plt.subplot(111)
#      17 x = np.array([0, 50, 100, 200, 400, 600, 1000, 1500, 2000])
# ---> 18 plot_signle_line(x, eeg, eeg_std, "EEG", "blue")
#      19 plot_signle_line(x, eog, eog_std, "EOG", "orange")
#      20 plot_signle_line(x, mm, mm_std, "Multimodal", "black")
#
# /tmp/ipykernel_789588/2503225198.py in plot_signle_line(x, y, yerr, label, color)
#       8
#       9 def plot_signle_line(x, y, yerr, label, color):
# ---> 10     plt.plot(x, y, color=color, label=label)
#      11     plt.scatter(x, y, color=color)
#      12     plt.fill_between(x, y - yerr, y + yerr, alpha=0.5)
#
# /esat/smcdata/users/kkontras/Image_Dataset/no_backup/envs/gl_env/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767     return gca().plot(
#    2768         *args, scalex=scalex, scaley=scaley,
# -> 2769         **({"data": data} if data is not None else {}), **kwargs)
#    2770
#    2771
#
# /esat/smcdata/users/kkontras/Image_Dataset/no_backup/envs/gl_env/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1633         """
#    1634         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1635         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1636         for line in lines:
#    1637             self.add_line(line)
#
# /esat/smcdata/users/kkontras/Image_Dataset/no_backup/envs/gl_env/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# /esat/smcdata/users/kkontras/Image_Dataset/no_backup/envs/gl_env/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (9,) and (8,)

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

eeg, eog, mm = np.array(eeg), np.array(eog), np.array(mm)
eeg_std, eog_std, mm_std = np.array(eeg_std), np.array(eog_std), np.array(mm_std)


def plot_signle_line(x, y, yerr, label, color):
    plt.plot(x, y, color=color, label=label)
    plt.scatter(x, y, color=color)
    plt.fill_between(x, y - yerr, y + yerr, alpha=0.5)


plt.figure(figsize=(10, 6))
ax = plt.subplot(111)
x = np.array([0, 50, 100, 200, 400, 600, 1000, 1500, 2000])
plot_signle_line(x, eeg, eeg_std, "EEG", "blue")
plot_signle_line(x, eog, eog_std, "EOG", "orange")
plot_signle_line(x, mm, mm_std, "Multimodal", "black")
plt.legend(fontsize=12, frameon=False, ncol=3, bbox_to_anchor=(0.28, 0.88))
plt.xlabel("Extra Single-Modality EOG Patients", fontsize=12)
plt.ylabel("Cohens Kappa", fontsize=12)
plt.xticks(x, fontsize=8)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.yticks([0.65, 0.70, 0.75, 0.80, 0.85], fontsize=8)
plt.xlim(-100, 2100)
plt.ylim(0.65, 0.85)
plt.title("Training with 100 EEG-EOG patients and EOG unimodal ones", fontsize=14)
plt.savefig("./incomplete_100c_0e_2000o.svg")
plt.show()
